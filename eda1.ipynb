# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import _pickle

# %%
with open('ads_details_df', 'rb') as f:
    df = _pickle.load(f)

# %%
df.head()
# Out:
#                                                  url       İlan no  \
# 0  https://www.hepsiemlak.com/istanbul-sisli-esen...    8272-25937
# 1  https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139860
# 2  https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139854
# 3  https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139729
# 4  https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139837
#
#   Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# 0            24-01-2023     Kiralık   Residence              2 + 1
# 1            19-01-2023     Kiralık       Daire              4 + 1
# 2            23-01-2023     Kiralık       Daire              3 + 2
# 3            11-01-2023     Kiralık       Daire              3 + 1
# 4            23-01-2023     Kiralık       Daire              3 + 1
#
#           Brüt / Net M2 Bulunduğu Kat   Bina Yaşı Isınma Tipi  ...  \
# 0  \n190m2\n \n/170m2\n        7. Kat  20 Yaşında     Merkezi  ...
# ...

# %% [markdown]
# # Son Güncelleme Tarihi

# %%
df['Son Güncelleme Tarihi']
# Out:
# 0        24-01-2023
# 1        19-01-2023
# 2        23-01-2023
# 3        11-01-2023
# 4        23-01-2023
#             ...
# 11445    25-01-2023
# 11446    24-01-2023
# 11447    25-01-2023
# 11448    25-01-2023
# 11449    24-01-2023
# Name: Son Güncelleme Tarihi, Length: 11450, dtype: object

# %%
df['Son Güncelleme Tarihi'] = pd.to_datetime(df['Son Güncelleme Tarihi'], format='%d-%m-%Y')
df['Son Güncelleme Tarihi']
# Out:
# 0       2023-01-24
# 1       2023-01-19
# 2       2023-01-23
# 3       2023-01-11
# 4       2023-01-23
#            ...
# 11445   2023-01-25
# 11446   2023-01-24
# 11447   2023-01-25
# 11448   2023-01-25
# 11449   2023-01-24
# Name: Son Güncelleme Tarihi, Length: 11450, dtype: datetime64[ns]

# %%
df['Son Güncelleme Tarihi'].min()
# Out:
# Timestamp('2022-11-10 00:00:00')

# %%
df['Son Güncelleme Tarihi'].max()
# Out:
# Timestamp('2023-01-25 00:00:00')

# %%
df[df['Son Güncelleme Tarihi'] <= pd.Timestamp('2022-12-10 00:00:00')]
# Out:
#                                                      url      İlan no  \
# 8      https://www.hepsiemlak.com/istanbul-besiktas-l...   8272-25777
# 24     https://www.hepsiemlak.com/istanbul-besiktas-u...   5575-12525
# 4014   https://www.hepsiemlak.com/istanbul-kadikoy-ac...    79026-401
# 4016   https://www.hepsiemlak.com/istanbul-beyoglu-ca...   0-39947335
# 4019   https://www.hepsiemlak.com/istanbul-bakirkoy-a...   0-39941720
# ...                                                  ...          ...
# 11215  https://www.hepsiemlak.com/istanbul-sisli-cumh...  89328-17013
# 11218  https://www.hepsiemlak.com/istanbul-sariyer-hu...  89328-16942
# 11220  https://www.hepsiemlak.com/istanbul-sariyer-ma...  89328-16931
# 11222  https://www.hepsiemlak.com/istanbul-eyupsultan...  89328-16976
# 11224  https://www.hepsiemlak.com/istanbul-besiktas-l...  89328-16937
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %% [markdown]
# # İlan Durumu

# %%
df['İlan Durumu'].unique()
# Out:
# array(['Kiralık'], dtype=object)

# %% [markdown]
# # Konut Şekli

# %%
len(df['Konut Şekli'].unique())
# Out:
# 13

# %%
df['Konut Şekli'].unique()
# Out:
# array(['Residence', 'Daire', 'Villa', 'Müstakil Ev', 'Yalı Dairesi',
#        'Yalı', 'Bina', 'Yazlık', 'Köşk', 'Köy Evi', 'Prefabrik',
#        'Çiftlik Evi', 'Kooperatif'], dtype=object)

# %%
df['Konut Şekli'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Oda + Salon Sayısı

# %%
df[df['Oda + Salon Sayısı'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, İlan no, Son Güncelleme Tarihi, İlan Durumu, Konut Şekli, Oda + Salon Sayısı, Brüt / Net M2, Bulunduğu Kat, Bina Yaşı, Isınma Tipi, Kat Sayısı, Eşya Durumu, Banyo Sayısı, Yapı Tipi, Yapının Durumu, Kullanım Durumu, Cephe, Yakıt Tipi, Yetkili Ofis, short_info, rent, Site İçerisinde, Aidat, Depozito, Tapu Durumu, Krediye Uygunluk, Takas, Kira Getirisi]
# Index: []
#
# [0 rows x 28 columns]

# %%
df['Oda + Salon Sayısı'].unique(), len(df['Oda + Salon Sayısı'].unique())
# Out:
# (array(['2 + 1', '4 + 1', '3 + 2', '3 + 1', '1 + 1', '10 + 2', '5 + 1',
#         '5 + 2', '1 + 0', '6 + 1', '8 + 3', '35 + 1', '8 + 1', '4 + 2',
#         '6 + 2', '2 + 2', '7 + 1', '4 + 3', '7 + 2', '9 + 1', '14 + 3',
#         '1 + 2', '11 + 1', '7 + 3', '1 + 3', '4 + 0', '10 + 1', '9 + 2',
#         '3 + 3', '6 + 3', '8 + 4', '10 + 3', '8 + 2', '1 + 11', '12 + 2',
#         '2 + 11', '5 + 0', '5 + 3', '3 + 0', '9 + 3', '3 + 11', '31 + 116',
#         '7 + 7', '3 + 12', '20 + 3', '10 + 0', '8 + 0', '12 + 4', '12 + 5',
#         '6 + 4', '2 + 0', '136 + 110', '6 + 0', '12 + 1', '52 + 1',
#         '16 + 3', '90 + 85', '14 + 2', '21 + 2', '11 + 2', '19 + 5',
#         '9 + 0', '5 + 5'], dtype=object),
#  63)

# %%
oda_salon_count = {}
for _, row in df.iterrows():
    val = row['Oda + Salon Sayısı']
    if val in oda_salon_count:
        oda_salon_count[val] += 1
    else:
        oda_salon_count[val] = 1

oda_salon_count
# Out:
# {'2 + 1': 3777,
#  '4 + 1': 787,
#  '3 + 2': 100,
#  '3 + 1': 3116,
#  '1 + 1': 2397,
#  '10 + 2': 8,
#  '5 + 1': 263,
#  '5 + 2': 157,
#  '1 + 0': 305,
#  '6 + 1': 75,
#  '8 + 3': 6,
#  '35 + 1': 1,
#  '8 + 1': 7,
#  '4 + 2': 162,
#  '6 + 2': 96,
#  '2 + 2': 26,
#  '7 + 1': 18,
#  '4 + 3': 2,
#  '7 + 2': 43,
#  '9 + 1': 3,
#  '14 + 3': 1,
#  '1 + 2': 5,
#  '11 + 1': 3,
#  '7 + 3': 7,
#  '1 + 3': 3,
#  '4 + 0': 2,
#  '10 + 1': 4,
#  '9 + 2': 3,
#  '3 + 3': 3,
#  '6 + 3': 4,
#  '8 + 4': 1,
#  '10 + 3': 1,
#  '8 + 2': 14,
#  '1 + 11': 2,
#  '12 + 2': 2,
#  '2 + 11': 2,
#  '5 + 0': 1,
#  '5 + 3': 3,
#  '3 + 0': 6,
#  '9 + 3': 4,
#  '3 + 11': 1,
#  '31 + 116': 1,
#  '7 + 7': 2,
#  '3 + 12': 1,
#  '20 + 3': 2,
#  '10 + 0': 2,
#  '8 + 0': 1,
#  '12 + 4': 2,
#  '12 + 5': 1,
#  '6 + 4': 1,
#  '2 + 0': 3,
#  '136 + 110': 1,
#  '6 + 0': 1,
#  '12 + 1': 1,
#  '52 + 1': 1,
#  '16 + 3': 1,
#  '90 + 85': 1,
#  '14 + 2': 1,
#  '21 + 2': 1,
#  '11 + 2': 2,
#  '19 + 5': 1,
#  '9 + 0': 1,
# ...

# %%
def get_proportions(threhsold):
    counter, sum_counter = 0, 0
    for v in oda_salon_count.values():
        if v < threhsold:
            counter += 1
            sum_counter += v
    print(counter, counter/len(oda_salon_count))
    print(sum_counter, sum_counter/len(df))
    print()

# %%
for t in [20, 30, 40, 50, 100]:
    get_proportions(t)
# Out:
# 50 0.7936507936507936
# 146 0.012751091703056768
#
# 51 0.8095238095238095
# 172 0.01502183406113537
#
# 51 0.8095238095238095
# 172 0.01502183406113537
#
# 52 0.8253968253968254
# 215 0.018777292576419215
#
# 54 0.8571428571428571
# 386 0.0337117903930131

# %%
# split the column into two

# %%
df[['oda_sayisi', 'salon_sayisi']] = df['Oda + Salon Sayısı'].str.split('+', 1, expand=True)
df[['oda_sayisi', 'salon_sayisi', 'Oda + Salon Sayısı']]
# Out:
#       oda_sayisi salon_sayisi Oda + Salon Sayısı
# 0             2             1              2 + 1
# 1             4             1              4 + 1
# 2             3             2              3 + 2
# 3             3             1              3 + 1
# 4             3             1              3 + 1
# ...          ...          ...                ...
# 11445         3             1              3 + 1
# 11446         3             1              3 + 1
# 11447         2             1              2 + 1
# 11448         1             0              1 + 0
# 11449         2             1              2 + 1
#
# [11450 rows x 3 columns]

# %% [markdown]
# # Brüt / Net M2

# %%
df[df['Brüt / Net M2'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, İlan no, Son Güncelleme Tarihi, İlan Durumu, Konut Şekli, Oda + Salon Sayısı, Brüt / Net M2, Bulunduğu Kat, Bina Yaşı, Isınma Tipi, Kat Sayısı, Eşya Durumu, Banyo Sayısı, Yapı Tipi, Yapının Durumu, Kullanım Durumu, Cephe, Yakıt Tipi, Yetkili Ofis, short_info, rent, Site İçerisinde, Aidat, Depozito, Tapu Durumu, Krediye Uygunluk, Takas, Kira Getirisi, oda_sayisi, salon_sayisi]
# Index: []
#
# [0 rows x 30 columns]

# %%
df['Brüt / Net M2'] = df['Brüt / Net M2'].str.replace('\n', '').str.replace(' ', '').str.replace('m2', '').str.replace('.', '')
df[['Brüt M2', 'Net M2']] = df['Brüt / Net M2'].str.split('/', 1, expand=True)

df['Brüt M2'] = pd.to_numeric(df['Brüt M2'], errors='coerce')
df['Net M2'] = pd.to_numeric(df['Net M2'], errors='coerce')

df[['Brüt / Net M2', 'Brüt M2', 'Net M2']]
# Out:
#       Brüt / Net M2  Brüt M2  Net M2
# 0           190/170      190   170.0
# 1           220/190      220   190.0
# 2           235/190      235   190.0
# 3           135/110      135   110.0
# 4           270/250      270   250.0
# ...             ...      ...     ...
# 11445       128/107      128   107.0
# 11446       140/120      140   120.0
# 11447         80/75       80    75.0
# 11448         65/55       65    55.0
# 11449         95/90       95    90.0
#
# [11450 rows x 3 columns]

# %% [markdown]
# # Bulunduğu Kat

# %%
df['Bulunduğu Kat']
# Out:
# 0              7. Kat
# 1              4. Kat
# 2              3. Kat
# 3              2. Kat
# 4              2. Kat
#              ...
# 11445          1. Kat
# 11446    Yüksek Giriş
# 11447    Yüksek Giriş
# 11448     21 ve üzeri
# 11449          1. Kat
# Name: Bulunduğu Kat, Length: 11450, dtype: object

# %%
df[df['Bulunduğu Kat'].isna()]
# Out:
#                                                      url     İlan no  \
# 45     https://www.hepsiemlak.com/istanbul-sariyer-em...   2608-4246
# 73     https://www.hepsiemlak.com/istanbul-besiktas-a...  63901-2153
# 88     https://www.hepsiemlak.com/istanbul-uskudar-me...   71783-712
# 112    https://www.hepsiemlak.com/istanbul-sariyer-re...  46572-9764
# 130    https://www.hepsiemlak.com/istanbul-beyoglu-su...   48256-840
# ...                                                  ...         ...
# 11399  https://www.hepsiemlak.com/istanbul-uskudar-ku...  10656-1242
# 11417  https://www.hepsiemlak.com/istanbul-cekmekoy-r...  118469-339
# 11424  https://www.hepsiemlak.com/istanbul-sariyer-ma...  87327-1168
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11442  https://www.hepsiemlak.com/istanbul-beykoz-gum...  0-40195656
#
#       Son Güncelleme Tarihi İlan Durumu  Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df['Bulunduğu Kat'].unique(), len(df['Bulunduğu Kat'].unique())
# Out:
# (array(['7. Kat', '4. Kat', '3. Kat', '2. Kat', '5. Kat', '21 ve üzeri',
#         'Ara Kat', '11. Kat', '14. Kat', '18. Kat', 'Bahçe Katı', '1. Kat',
#         '6. Kat', '8. Kat', 'Yüksek Giriş', nan, '13. Kat', 'En Üst Kat',
#         '20. Kat', 'Çatı Katı', '10. Kat', 'Kot 2', '9. Kat', 'Giriş Katı',
#         'Zemin', 'Teras Katı', '19. Kat', 'Kot 1', '17. Kat', '16. Kat',
#         '12. Kat', 'Villa Katı', 'Bodrum', '15. Kat', 'Kot 3',
#         'Yarı Bodrum', 'Tripleks', 'Asma Kat', 'Bodrum ve Zemin'],
#        dtype=object),
#  39)

# %%
df_cpy = df.copy()
df_cpy['Bulunduğu Kat'] = df_cpy['Bulunduğu Kat'].fillna('-')
df_cpy[df_cpy['Bulunduğu Kat'] == '-']
# Out:
#                                                      url     İlan no  \
# 45     https://www.hepsiemlak.com/istanbul-sariyer-em...   2608-4246
# 73     https://www.hepsiemlak.com/istanbul-besiktas-a...  63901-2153
# 88     https://www.hepsiemlak.com/istanbul-uskudar-me...   71783-712
# 112    https://www.hepsiemlak.com/istanbul-sariyer-re...  46572-9764
# 130    https://www.hepsiemlak.com/istanbul-beyoglu-su...   48256-840
# ...                                                  ...         ...
# 11399  https://www.hepsiemlak.com/istanbul-uskudar-ku...  10656-1242
# 11417  https://www.hepsiemlak.com/istanbul-cekmekoy-r...  118469-339
# 11424  https://www.hepsiemlak.com/istanbul-sariyer-ma...  87327-1168
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11442  https://www.hepsiemlak.com/istanbul-beykoz-gum...  0-40195656
#
#       Son Güncelleme Tarihi İlan Durumu  Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
bulundugu_kat_count = {}
for _, row in df_cpy.iterrows():
    val = row['Bulunduğu Kat']
    if val in bulundugu_kat_count:
        bulundugu_kat_count[val] += 1
    else:
        bulundugu_kat_count[val] = 1

bulundugu_kat_count
# Out:
# {'7. Kat': 294,
#  '4. Kat': 951,
#  '3. Kat': 1182,
#  '2. Kat': 1160,
#  '5. Kat': 605,
#  '21 ve üzeri': 557,
#  'Ara Kat': 873,
#  '11. Kat': 137,
#  '14. Kat': 103,
#  '18. Kat': 58,
#  'Bahçe Katı': 756,
#  '1. Kat': 957,
#  '6. Kat': 353,
#  '8. Kat': 273,
#  'Yüksek Giriş': 490,
#  '-': 580,
#  '13. Kat': 105,
#  'En Üst Kat': 292,
#  '20. Kat': 64,
#  'Çatı Katı': 156,
#  '10. Kat': 191,
#  'Kot 2': 43,
#  '9. Kat': 195,
#  'Giriş Katı': 350,
#  'Zemin': 47,
#  'Teras Katı': 45,
#  '19. Kat': 45,
#  'Kot 1': 76,
#  '17. Kat': 60,
#  '16. Kat': 86,
#  '12. Kat': 132,
#  'Villa Katı': 39,
#  'Bodrum': 21,
#  '15. Kat': 113,
#  'Kot 3': 21,
#  'Yarı Bodrum': 34,
#  'Tripleks': 3,
#  'Asma Kat': 1,
#  'Bodrum ve Zemin': 2}

# %% [markdown]
# # Bina Yaşı

# %%
df[df['Bina Yaşı'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, İlan no, Son Güncelleme Tarihi, İlan Durumu, Konut Şekli, Oda + Salon Sayısı, Brüt / Net M2, Bulunduğu Kat, Bina Yaşı, Isınma Tipi, Kat Sayısı, Eşya Durumu, Banyo Sayısı, Yapı Tipi, Yapının Durumu, Kullanım Durumu, Cephe, Yakıt Tipi, Yetkili Ofis, short_info, rent, Site İçerisinde, Aidat, Depozito, Tapu Durumu, Krediye Uygunluk, Takas, Kira Getirisi, oda_sayisi, salon_sayisi, Brüt M2, Net M2]
# Index: []
#
# [0 rows x 32 columns]

# %%
df['Bina Yaşı'].unique()
# Out:
# array(['20 Yaşında', '16 Yaşında', '32 Yaşında', '35 Yaşında',
#        '10 Yaşında', '30 Yaşında', '15 Yaşında', '4 Yaşında', '5 Yaşında',
#        '12 Yaşında', '25 Yaşında', 'Sıfır Bina', '18 Yaşında',
#        '26 Yaşında', '14 Yaşında', '2 Yaşında', '1 Yaşında', '23 Yaşında',
#        '31 Yaşında', '24 Yaşında', '9 Yaşında', '50 Yaşında',
#        '45 Yaşında', '11 Yaşında', '40 Yaşında', '3 Yaşında',
#        '21 Yaşında', '27 Yaşında', '6 Yaşında', '19 Yaşında', '8 Yaşında',
#        '7 Yaşında', '13 Yaşında', '39 Yaşında', '38 Yaşında',
#        '28 Yaşında', '33 Yaşında', '47 Yaşında', '22 Yaşında',
#        '17 Yaşında', '34 Yaşında', '55 Yaşında', '43 Yaşında',
#        '100 Yaşında', '42 Yaşında', '36 Yaşında', '29 Yaşında',
#        '41 Yaşında', '70 Yaşında', '80 Yaşında', '60 Yaşında',
#        '99 Yaşında', '37 Yaşında', '90 Yaşında', '44 Yaşında',
#        '48 Yaşında', '52 Yaşında', '65 Yaşında', '96 Yaşında',
# ...

# %%
bina_yasi_count = {}
for _, row in df.iterrows():
    val = row['Bina Yaşı']
    if val in bina_yasi_count:
        bina_yasi_count[val] += 1
    else:
        bina_yasi_count[val] = 1

bina_yasi_count
# Out:
# {'20 Yaşında': 424,
#  '16 Yaşında': 236,
#  '32 Yaşında': 46,
#  '35 Yaşında': 341,
#  '10 Yaşında': 613,
#  '30 Yaşında': 762,
#  '15 Yaşında': 397,
#  '4 Yaşında': 734,
#  '5 Yaşında': 1208,
#  '12 Yaşında': 178,
#  '25 Yaşında': 590,
#  'Sıfır Bina': 1323,
#  '18 Yaşında': 72,
#  '26 Yaşında': 209,
#  '14 Yaşında': 50,
#  '2 Yaşında': 382,
#  '1 Yaşında': 477,
#  '23 Yaşında': 65,
#  '31 Yaşında': 255,
#  '24 Yaşında': 51,
#  '9 Yaşında': 93,
#  '50 Yaşında': 87,
#  '45 Yaşında': 87,
#  '11 Yaşında': 375,
#  '40 Yaşında': 315,
#  '3 Yaşında': 385,
#  '21 Yaşında': 205,
#  '27 Yaşında': 56,
#  '6 Yaşında': 233,
#  '19 Yaşında': 14,
#  '8 Yaşında': 272,
#  '7 Yaşında': 324,
#  '13 Yaşında': 75,
#  '39 Yaşında': 9,
#  '38 Yaşında': 25,
#  '28 Yaşında': 87,
#  '33 Yaşında': 32,
#  '47 Yaşında': 3,
#  '22 Yaşında': 97,
#  '17 Yaşında': 58,
#  '34 Yaşında': 14,
#  '55 Yaşında': 9,
#  '43 Yaşında': 3,
#  '100 Yaşında': 14,
#  '42 Yaşında': 13,
#  '36 Yaşında': 17,
#  '29 Yaşında': 30,
# ...

# %%
df['bina yasi'] = df['Bina Yaşı'].str.replace('Sıfır Bina', '0').str.replace(' Yaşında', '')
df['bina yasi'] = df['bina yasi'].astype('int')
df
# Out:
#                                                      url       İlan no  \
# 0      https://www.hepsiemlak.com/istanbul-sisli-esen...    8272-25937
# 1      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139860
# 2      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139854
# 3      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139729
# 4      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139837
# ...                                                  ...           ...
# 11445  https://www.hepsiemlak.com/istanbul-sariyer-ma...    77755-1835
# 11446  https://www.hepsiemlak.com/istanbul-kadikoy-ca...     1652-3606
# 11447  https://www.hepsiemlak.com/istanbul-uskudar-va...    130870-172
# 11448  https://www.hepsiemlak.com/istanbul-sariyer-hu...   69537-76910
# 11449  https://www.hepsiemlak.com/istanbul-sisli-merk...    46376-2283
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df.drop(df[df['bina yasi'] > 100].index)['bina yasi'].hist()
# Out:
# <AxesSubplot:>

# %%
df.drop(df[df['bina yasi'] > 100].index).boxplot(column='bina yasi')
# Out:
# <AxesSubplot:>

# %%
drop_indices = list(df[df['rent'] >= 1e5].index)
drop_indices.extend(list(df[df['bina yasi'] > 100].index))
# drop_indices

# %%
plt.scatter(df.drop(drop_indices)['bina yasi'], df.drop(drop_indices)['rent'])

# %% [markdown]
# # Isınma Tipi

# %%
df[df['Isınma Tipi'].isna()]
# Out:
# Empty DataFrame
# Columns: [url, İlan no, Son Güncelleme Tarihi, İlan Durumu, Konut Şekli, Oda + Salon Sayısı, Brüt / Net M2, Bulunduğu Kat, Bina Yaşı, Isınma Tipi, Kat Sayısı, Eşya Durumu, Banyo Sayısı, Yapı Tipi, Yapının Durumu, Kullanım Durumu, Cephe, Yakıt Tipi, Yetkili Ofis, short_info, rent, Site İçerisinde, Aidat, Depozito, Tapu Durumu, Krediye Uygunluk, Takas, Kira Getirisi, oda_sayisi, salon_sayisi, Brüt M2, Net M2, bina yasi]
# Index: []
#
# [0 rows x 33 columns]

# %%
df['Isınma Tipi'].unique(), len(df['Isınma Tipi'].unique())
# Out:
# (array(['Merkezi', 'Kombi', 'Merkezi (Pay Ölçer)', 'Yerden Isıtma', 'VRV',
#         'Klima', 'Fancoil Ünitesi', 'Doğalgaz Sobası', 'Soba',
#         'Belirtilmemiş', 'Kat Kaloriferi', 'Isıtma Yok',
#         'Jeotermal Isıtma', 'Güneş Enerjisi', 'Isı Pompası'], dtype=object),
#  15)

# %%
isinma_tipi_count = {}
for _, row in df.iterrows():
    val = row['Isınma Tipi']
    if val in isinma_tipi_count:
        isinma_tipi_count[val] += 1
    else:
        isinma_tipi_count[val] = 1

isinma_tipi_count
# Out:
# {'Merkezi': 1292,
#  'Kombi': 6373,
#  'Merkezi (Pay Ölçer)': 2971,
#  'Yerden Isıtma': 314,
#  'VRV': 62,
#  'Klima': 106,
#  'Fancoil Ünitesi': 74,
#  'Doğalgaz Sobası': 53,
#  'Soba': 67,
#  'Belirtilmemiş': 34,
#  'Kat Kaloriferi': 59,
#  'Isıtma Yok': 40,
#  'Jeotermal Isıtma': 2,
#  'Güneş Enerjisi': 2,
#  'Isı Pompası': 1}

# %% [markdown]
# # Kat Sayısı

# %%
df[df['Kat Sayısı'].isna()]
# Out:
#                                                      url     İlan no  \
# 2168   https://www.hepsiemlak.com/istanbul-beykoz-tok...  128504-312
# 2656   https://www.hepsiemlak.com/istanbul-avcilar-am...  106678-903
# 3055   https://www.hepsiemlak.com/istanbul-esenyurt-g...  0-40167886
# 3064   https://www.hepsiemlak.com/istanbul-sariyer-em...   135070-18
# 3071   https://www.hepsiemlak.com/istanbul-gaziosmanp...  0-40151985
# 3230   https://www.hepsiemlak.com/istanbul-adalar-mad...   54895-877
# 4268   https://www.hepsiemlak.com/istanbul-umraniye-a...  0-40120419
# 4833   https://www.hepsiemlak.com/istanbul-beylikduzu...  0-40049601
# 5170   https://www.hepsiemlak.com/istanbul-sultangazi...  124094-878
# 7962   https://www.hepsiemlak.com/istanbul-beyoglu-ku...  117700-185
# 9076   https://www.hepsiemlak.com/istanbul-fatih-sehs...   125197-80
# 9097   https://www.hepsiemlak.com/istanbul-esenyurt-k...   132004-20
# 9111   https://www.hepsiemlak.com/istanbul-adalar-bur...  0-32279808
# ...

# %%
df['Kat Sayısı'].unique(), len(df['Kat Sayısı'].unique())
# Out:
# (array(['15 Katlı', '5 Katlı', '3 Katlı', '52 Katlı', '4 Katlı',
#         '12 Katlı', '18 Katlı', '9 Katlı', '47 Katlı', '45 Katlı',
#         '30 Katlı', '22 Katlı', '44 Katlı', '16 Katlı', '7 Katlı',
#         '10 Katlı', '26 Katlı', '6 Katlı', '14 Katlı', '8 Katlı',
#         '42 Katlı', '2 Katlı', '33 Katlı', '13 Katlı', '11 Katlı',
#         '17 Katlı', '35 Katlı', '25 Katlı', '21 Katlı', '54 Katlı',
#         '32 Katlı', '24 Katlı', '41 Katlı', '40 Katlı', '23 Katlı',
#         '27 Katlı', '1 Katlı', '50 Katlı', '65 Katlı', '20 Katlı',
#         '29 Katlı', '43 Katlı', '28 Katlı', '19 Katlı', '55 Katlı',
#         '31 Katlı', '34 Katlı', '48 Katlı', '36 Katlı', '39 Katlı', nan,
#         '110 Katlı', '38 Katlı', '53 Katlı', '51 Katlı', '63 Katlı',
#         '37 Katlı', '61 Katlı', '60 Katlı', '46 Katlı', '56 Katlı',
#         '62 Katlı', '49 Katlı', '59 Katlı'], dtype=object),
#  64)

# %%
df['kat sayisi'] = df['Kat Sayısı'].fillna('-')
df[df['kat sayisi'] == '-']
# Out:
#                                                      url     İlan no  \
# 2168   https://www.hepsiemlak.com/istanbul-beykoz-tok...  128504-312
# 2656   https://www.hepsiemlak.com/istanbul-avcilar-am...  106678-903
# 3055   https://www.hepsiemlak.com/istanbul-esenyurt-g...  0-40167886
# 3064   https://www.hepsiemlak.com/istanbul-sariyer-em...   135070-18
# 3071   https://www.hepsiemlak.com/istanbul-gaziosmanp...  0-40151985
# 3230   https://www.hepsiemlak.com/istanbul-adalar-mad...   54895-877
# 4268   https://www.hepsiemlak.com/istanbul-umraniye-a...  0-40120419
# 4833   https://www.hepsiemlak.com/istanbul-beylikduzu...  0-40049601
# 5170   https://www.hepsiemlak.com/istanbul-sultangazi...  124094-878
# 7962   https://www.hepsiemlak.com/istanbul-beyoglu-ku...  117700-185
# 9076   https://www.hepsiemlak.com/istanbul-fatih-sehs...   125197-80
# 9097   https://www.hepsiemlak.com/istanbul-esenyurt-k...   132004-20
# 9111   https://www.hepsiemlak.com/istanbul-adalar-bur...  0-32279808
# ...

# %%
kat_sayisi_count = {}
for _, row in df.iterrows():
    val = row['kat sayisi']
    if val in kat_sayisi_count:
        kat_sayisi_count[val] += 1
    else:
        kat_sayisi_count[val] = 1

kat_sayisi_count
# Out:
# {'15 Katlı': 313,
#  '5 Katlı': 2293,
#  '3 Katlı': 1208,
#  '52 Katlı': 24,
#  '4 Katlı': 2199,
#  '12 Katlı': 215,
#  '18 Katlı': 124,
#  '9 Katlı': 224,
#  '47 Katlı': 7,
#  '45 Katlı': 66,
#  '30 Katlı': 494,
#  '22 Katlı': 53,
#  '44 Katlı': 76,
#  '16 Katlı': 139,
#  '7 Katlı': 337,
#  '10 Katlı': 278,
#  '26 Katlı': 18,
#  '6 Katlı': 734,
#  '14 Katlı': 208,
#  '8 Katlı': 301,
#  '42 Katlı': 78,
#  '2 Katlı': 371,
#  '33 Katlı': 105,
#  '13 Katlı': 177,
#  '11 Katlı': 170,
#  '17 Katlı': 133,
#  '35 Katlı': 42,
#  '25 Katlı': 51,
#  '21 Katlı': 42,
#  '54 Katlı': 11,
#  '32 Katlı': 55,
#  '24 Katlı': 73,
#  '41 Katlı': 4,
#  '40 Katlı': 77,
#  '23 Katlı': 45,
#  '27 Katlı': 60,
#  '1 Katlı': 95,
#  '50 Katlı': 28,
#  '65 Katlı': 9,
#  '20 Katlı': 175,
#  '29 Katlı': 23,
#  '43 Katlı': 7,
#  '28 Katlı': 15,
#  '19 Katlı': 78,
#  '55 Katlı': 9,
#  '31 Katlı': 21,
#  '34 Katlı': 21,
#  '48 Katlı': 89,
#  '36 Katlı': 16,
#  '39 Katlı': 12,
#  '-': 17,
#  '110 Katlı': 1,
# ...

# %%
df['kat sayisi'] = pd.to_numeric(df['kat sayisi'].str.replace(' Katlı', ''), errors='coerce')
df['kat sayisi']
# Out:
# 0        15.0
# 1         5.0
# 2         3.0
# 3         5.0
# 4         5.0
#          ...
# 11445    40.0
# 11446    10.0
# 11447     5.0
# 11448    55.0
# 11449     4.0
# Name: kat sayisi, Length: 11450, dtype: float64

# %%
df[df['kat sayisi'].isna()]
# Out:
#                                                      url     İlan no  \
# 2168   https://www.hepsiemlak.com/istanbul-beykoz-tok...  128504-312
# 2656   https://www.hepsiemlak.com/istanbul-avcilar-am...  106678-903
# 3055   https://www.hepsiemlak.com/istanbul-esenyurt-g...  0-40167886
# 3064   https://www.hepsiemlak.com/istanbul-sariyer-em...   135070-18
# 3071   https://www.hepsiemlak.com/istanbul-gaziosmanp...  0-40151985
# 3230   https://www.hepsiemlak.com/istanbul-adalar-mad...   54895-877
# 4268   https://www.hepsiemlak.com/istanbul-umraniye-a...  0-40120419
# 4833   https://www.hepsiemlak.com/istanbul-beylikduzu...  0-40049601
# 5170   https://www.hepsiemlak.com/istanbul-sultangazi...  124094-878
# 7962   https://www.hepsiemlak.com/istanbul-beyoglu-ku...  117700-185
# 9076   https://www.hepsiemlak.com/istanbul-fatih-sehs...   125197-80
# 9097   https://www.hepsiemlak.com/istanbul-esenyurt-k...   132004-20
# 9111   https://www.hepsiemlak.com/istanbul-adalar-bur...  0-32279808
# ...

# %% [markdown]
# # Eşya Durumu

# %%
df[df['Eşya Durumu'].isna()]
# Out:
#                                                      url      İlan no  \
# 9      https://www.hepsiemlak.com/istanbul-kadikoy-su...   1100-11646
# 10     https://www.hepsiemlak.com/istanbul-kadikoy-su...   1100-11645
# 20     https://www.hepsiemlak.com/istanbul-besiktas-l...    119257-32
# 34     https://www.hepsiemlak.com/istanbul-besiktas-n...   8525-54691
# 39     https://www.hepsiemlak.com/istanbul-kadikoy-fe...    7005-1238
# ...                                                  ...          ...
# 11403  https://www.hepsiemlak.com/istanbul-beykoz-cub...   49688-1247
# 11411  https://www.hepsiemlak.com/istanbul-sisli-eski...  1172-186435
# 11415  https://www.hepsiemlak.com/istanbul-kagithane-...  118239-3479
# 11434  https://www.hepsiemlak.com/istanbul-kagithane-...  118239-3478
# 11440  https://www.hepsiemlak.com/istanbul-atasehir-b...  1172-186434
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df['Eşya Durumu'].unique()
# Out:
# array(['Eşyalı', 'Eşyalı Değil', nan], dtype=object)

# %%
df['esyali'] = df['Eşya Durumu'].fillna('Eşyalı Değil')

df['esyali'] = df['esyali'].str.replace('Eşyalı Değil', '0')
df['esyali'] = df['esyali'].replace('Eşyalı', '1')
df['esyali'] = df['esyali'].astype('int')

df['esyali']
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 11445    1
# 11446    0
# 11447    0
# 11448    1
# 11449    1
# Name: esyali, Length: 11450, dtype: int32

# %%
df['esyali'].sum()
# Out:
# 4489

# %%
df['esyali'].sum() == len(df[df['Eşya Durumu']=='Eşyalı'])
# Out:
# True

# %% [markdown]
# # Banyo Sayısı

# %%
df[df['Banyo Sayısı'].isna()]
# Out:
#                                                      url      İlan no  \
# 1060   https://www.hepsiemlak.com/istanbul-kadikoy-os...    80253-672
# 1506   https://www.hepsiemlak.com/istanbul-esenyurt-c...   106678-895
# 3735   https://www.hepsiemlak.com/istanbul-beylikduzu...    3089-9265
# 4268   https://www.hepsiemlak.com/istanbul-umraniye-a...   0-40120419
# 4833   https://www.hepsiemlak.com/istanbul-beylikduzu...   0-40049601
# 5380   https://www.hepsiemlak.com/istanbul-kucukcekme...   128093-145
# 9212   https://www.hepsiemlak.com/istanbul-uskudar-ki...    130306-35
# 9514   https://www.hepsiemlak.com/istanbul-sariyer-em...   23180-5563
# 9884   https://www.hepsiemlak.com/istanbul-fatih-koca...   0-38058216
# 10082  https://www.hepsiemlak.com/istanbul-bagcilar-c...   0-38805517
# 10312  https://www.hepsiemlak.com/istanbul-sariyer-ay...  119728-1631
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df['Banyo Sayısı'].unique(), len(df['Banyo Sayısı'].unique())
# Out:
# (array(['2', '3', '1', '4', '6', '7', '5', nan, '21', '10', '8', '17',
#         '12', '9', '11', '16'], dtype=object),
#  16)

# %%
df['banyo sayisi'] = df['Banyo Sayısı'].fillna('-')
df[df['banyo sayisi'] == '-']
# Out:
#                                                      url      İlan no  \
# 1060   https://www.hepsiemlak.com/istanbul-kadikoy-os...    80253-672
# 1506   https://www.hepsiemlak.com/istanbul-esenyurt-c...   106678-895
# 3735   https://www.hepsiemlak.com/istanbul-beylikduzu...    3089-9265
# 4268   https://www.hepsiemlak.com/istanbul-umraniye-a...   0-40120419
# 4833   https://www.hepsiemlak.com/istanbul-beylikduzu...   0-40049601
# 5380   https://www.hepsiemlak.com/istanbul-kucukcekme...   128093-145
# 9212   https://www.hepsiemlak.com/istanbul-uskudar-ki...    130306-35
# 9514   https://www.hepsiemlak.com/istanbul-sariyer-em...   23180-5563
# 9884   https://www.hepsiemlak.com/istanbul-fatih-koca...   0-38058216
# 10082  https://www.hepsiemlak.com/istanbul-bagcilar-c...   0-38805517
# 10312  https://www.hepsiemlak.com/istanbul-sariyer-ay...  119728-1631
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
banyo_sayisi_count = {}
for _, row in df.iterrows():
    val = row['banyo sayisi']
    if val in banyo_sayisi_count:
        banyo_sayisi_count[val] += 1
    else:
        banyo_sayisi_count[val] = 1

banyo_sayisi_count
# Out:
# {'2': 3198,
#  '3': 776,
#  '1': 6877,
#  '4': 360,
#  '6': 51,
#  '7': 25,
#  '5': 135,
#  '-': 11,
#  '21': 1,
#  '10': 3,
#  '8': 6,
#  '17': 1,
#  '12': 1,
#  '9': 2,
#  '11': 2,
#  '16': 1}

# %%
df['banyo sayisi'] = pd.to_numeric(df['banyo sayisi'], errors='coerce')
df['banyo sayisi']
# Out:
# 0        2.0
# 1        2.0
# 2        3.0
# 3        2.0
# 4        3.0
#         ...
# 11445    2.0
# 11446    1.0
# 11447    1.0
# 11448    1.0
# 11449    1.0
# Name: banyo sayisi, Length: 11450, dtype: float64

# %% [markdown]
# # Yapı Tipi

# %%
df[df['Yapı Tipi'].isna()]
# Out:
#                                                      url     İlan no  \
# 7      https://www.hepsiemlak.com/istanbul-sisli-mesr...  121012-208
# 37     https://www.hepsiemlak.com/istanbul-beyoglu-as...    131227-9
# 44     https://www.hepsiemlak.com/istanbul-besiktas-b...  38942-1924
# 47     https://www.hepsiemlak.com/istanbul-atasehir-i...   131698-28
# 48     https://www.hepsiemlak.com/istanbul-atasehir-y...   131698-16
# ...                                                  ...         ...
# 11428  https://www.hepsiemlak.com/istanbul-kagithane-...  46572-9790
# 11433  https://www.hepsiemlak.com/istanbul-umraniye-a...  48423-3410
# 11437  https://www.hepsiemlak.com/istanbul-sariyer-ze...   73731-677
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11444  https://www.hepsiemlak.com/istanbul-kagithane-...  23180-5607
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df['Yapı Tipi'].unique(), len(df['Yapı Tipi'].unique())
# Out:
# (array(['Betonarme', nan, 'Çelik', 'Kagir', 'Ahşap', 'Taş Bina', 'Yığma',
#         'Prefabrik', 'Kütük'], dtype=object),
#  9)

# %%
df['yapi tipi'] = df['Yapı Tipi'].fillna('-')
df[df['yapi tipi'] == '-']
# Out:
#                                                      url     İlan no  \
# 7      https://www.hepsiemlak.com/istanbul-sisli-mesr...  121012-208
# 37     https://www.hepsiemlak.com/istanbul-beyoglu-as...    131227-9
# 44     https://www.hepsiemlak.com/istanbul-besiktas-b...  38942-1924
# 47     https://www.hepsiemlak.com/istanbul-atasehir-i...   131698-28
# 48     https://www.hepsiemlak.com/istanbul-atasehir-y...   131698-16
# ...                                                  ...         ...
# 11428  https://www.hepsiemlak.com/istanbul-kagithane-...  46572-9790
# 11433  https://www.hepsiemlak.com/istanbul-umraniye-a...  48423-3410
# 11437  https://www.hepsiemlak.com/istanbul-sariyer-ze...   73731-677
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11444  https://www.hepsiemlak.com/istanbul-kagithane-...  23180-5607
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
yapi_tipi_count = {}
for _, row in df.iterrows():
    val = row['yapi tipi']
    if val in yapi_tipi_count:
        yapi_tipi_count[val] += 1
    else:
        yapi_tipi_count[val] = 1

yapi_tipi_count
# Out:
# {'Betonarme': 7581,
#  '-': 3522,
#  'Çelik': 136,
#  'Kagir': 101,
#  'Ahşap': 43,
#  'Taş Bina': 36,
#  'Yığma': 24,
#  'Prefabrik': 4,
#  'Kütük': 3}

# %% [markdown]
# # Yapının Durumu

# %%
df[df['Yapının Durumu'].isna()]
# Out:
#                                                      url     İlan no  \
# 7      https://www.hepsiemlak.com/istanbul-sisli-mesr...  121012-208
# 37     https://www.hepsiemlak.com/istanbul-beyoglu-as...    131227-9
# 39     https://www.hepsiemlak.com/istanbul-kadikoy-fe...   7005-1238
# 44     https://www.hepsiemlak.com/istanbul-besiktas-b...  38942-1924
# 47     https://www.hepsiemlak.com/istanbul-atasehir-i...   131698-28
# ...                                                  ...         ...
# 11433  https://www.hepsiemlak.com/istanbul-umraniye-a...  48423-3410
# 11436  https://www.hepsiemlak.com/istanbul-avcilar-un...   134182-26
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11444  https://www.hepsiemlak.com/istanbul-kagithane-...  23180-5607
# 11445  https://www.hepsiemlak.com/istanbul-sariyer-ma...  77755-1835
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df['Yapının Durumu'].unique(), len(df['Yapının Durumu'].unique())
# Out:
# (array(['İkinci El', 'Sıfır', nan, 'Betonarme', 'Yapım Aşamasında'],
#        dtype=object),
#  5)

# %%
df['yapinin durumu'] = df['Yapının Durumu'].fillna('-')
df[df['yapinin durumu'] == '-']
# Out:
#                                                      url     İlan no  \
# 7      https://www.hepsiemlak.com/istanbul-sisli-mesr...  121012-208
# 37     https://www.hepsiemlak.com/istanbul-beyoglu-as...    131227-9
# 39     https://www.hepsiemlak.com/istanbul-kadikoy-fe...   7005-1238
# 44     https://www.hepsiemlak.com/istanbul-besiktas-b...  38942-1924
# 47     https://www.hepsiemlak.com/istanbul-atasehir-i...   131698-28
# ...                                                  ...         ...
# 11433  https://www.hepsiemlak.com/istanbul-umraniye-a...  48423-3410
# 11436  https://www.hepsiemlak.com/istanbul-avcilar-un...   134182-26
# 11438  https://www.hepsiemlak.com/istanbul-beykoz-yav...   2675-9380
# 11444  https://www.hepsiemlak.com/istanbul-kagithane-...  23180-5607
# 11445  https://www.hepsiemlak.com/istanbul-sariyer-ma...  77755-1835
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
yapinin_durumu_count = {}
for _, row in df.iterrows():
    val = row['yapinin durumu']
    if val in yapinin_durumu_count:
        yapinin_durumu_count[val] += 1
    else:
        yapinin_durumu_count[val] = 1

yapinin_durumu_count
# Out:
# {'İkinci El': 6225,
#  'Sıfır': 1689,
#  '-': 3512,
#  'Betonarme': 19,
#  'Yapım Aşamasında': 5}

# %%
df['yapinin durumu'] = df['yapinin durumu'].str.replace('Betonarme', '-')
df['yapinin durumu'] = df['yapinin durumu'].str.replace('Yapım Aşamasında', 'Sıfır')

# %%
yapinin_durumu_count = {}
for _, row in df.iterrows():
    val = row['yapinin durumu']
    if val in yapinin_durumu_count:
        yapinin_durumu_count[val] += 1
    else:
        yapinin_durumu_count[val] = 1

yapinin_durumu_count
# Out:
# {'İkinci El': 6225, 'Sıfır': 1694, '-': 3531}

# %%
df[df['yapinin durumu']=='-'][['yapinin durumu', 'bina yasi']]
# Out:
#       yapinin durumu  bina yasi
# 7                  -         30
# 37                 -         31
# 39                 -          0
# 44                 -         30
# 47                 -         10
# ...              ...        ...
# 11433              -         11
# 11436              -          0
# 11438              -         11
# 11444              -          0
# 11445              -          7
#
# [3531 rows x 2 columns]

# %%
age = 0
print(len(df[(df['yapinin durumu']=='-') & (df['bina yasi']==age)][['yapinin durumu', 'bina yasi']]))
print(len(df[(df['yapinin durumu']=='Sıfır') & (df['bina yasi']==age)][['yapinin durumu', 'bina yasi']]))
print(len(df[(df['yapinin durumu']=='İkinci El') & (df['bina yasi']==age)][['yapinin durumu', 'bina yasi']]))
# Out:
# 467
# 782
# 74

# %%
##############

# %%
df
# Out:
#                                                      url       İlan no  \
# 0      https://www.hepsiemlak.com/istanbul-sisli-esen...    8272-25937
# 1      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139860
# 2      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139854
# 3      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139729
# 4      https://www.hepsiemlak.com/istanbul-besiktas-u...  31303-139837
# ...                                                  ...           ...
# 11445  https://www.hepsiemlak.com/istanbul-sariyer-ma...    77755-1835
# 11446  https://www.hepsiemlak.com/istanbul-kadikoy-ca...     1652-3606
# 11447  https://www.hepsiemlak.com/istanbul-uskudar-va...    130870-172
# 11448  https://www.hepsiemlak.com/istanbul-sariyer-hu...   69537-76910
# 11449  https://www.hepsiemlak.com/istanbul-sisli-merk...    46376-2283
#
#       Son Güncelleme Tarihi İlan Durumu Konut Şekli Oda + Salon Sayısı  \
# ...

# %%
df.columns
# Out:
# Index(['url', 'İlan no', 'Son Güncelleme Tarihi', 'İlan Durumu', 'Konut Şekli',
#        'Oda + Salon Sayısı', 'Brüt / Net M2', 'Bulunduğu Kat', 'Bina Yaşı',
#        'Isınma Tipi', 'Kat Sayısı', 'Eşya Durumu', 'Banyo Sayısı', 'Yapı Tipi',
#        'Yapının Durumu', 'Kullanım Durumu', 'Cephe', 'Yakıt Tipi',
#        'Yetkili Ofis', 'short_info', 'rent', 'Site İçerisinde', 'Aidat',
#        'Depozito', 'Tapu Durumu', 'Krediye Uygunluk', 'Takas', 'Kira Getirisi',
#        'oda_sayisi', 'salon_sayisi', 'Brüt M2', 'Net M2', 'bina yasi'],
#       dtype='object')
