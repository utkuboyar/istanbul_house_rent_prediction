# %%
import pandas as pd
import numpy as np
import _pickle

import matplotlib.pyplot as plt

from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import mean_absolute_error

from sklearn.impute import SimpleImputer

# %%
with open('../regular_data_ready_for_model', 'rb') as f:
    df = _pickle.load(f)
df.head()
# Out:
#        rent   latitude  longitude oda_sayisi salon_sayisi  brut_m2  net_m2  \
# 8262  30000  41.043127  28.969064         2             1      100      75
# 8260   8000  40.979325  28.729905         3             1      145     130
# 7889  10000  41.057928  28.974291         3             1      110     100
# 7919  65000  41.152676  28.924586         3             1      165     121
# 7923  55000  41.207677  29.020296         6             2      450     430
#
#       bina_yasi  kat_sayisi  esyali  ...  binned_bulundugu_kat_cat_1  \
# 8262          1         8.0       1  ...                           0
# 8260         30         5.0       0  ...                           0
# 7889         15         5.0       0  ...                           0
# 7919          0         3.0       0  ...                           0
# 7923         16         4.0       0  ...                           0
#
#       binned_bulundugu_kat_cat_10  binned_bulundugu_kat_cat_11  \
# 8262                            0                            1
# 8260                            0                            1
# 7889                            0                            1
# 7919                            0                            0
# 7923                            1                            0
#
#       binned_bulundugu_kat_cat_2  binned_bulundugu_kat_cat_3  \
# 8262                           0                           0
# 8260                           0                           0
# 7889                           0                           0
# 7919                           0                           0
# 7923                           0                           0
#
#       binned_bulundugu_kat_cat_4  binned_bulundugu_kat_cat_6  \
# 8262                           0                           0
# 8260                           0                           0
# 7889                           0                           0
# 7919                           1                           0
# 7923                           0                           0
#
#       binned_bulundugu_kat_cat_7  binned_bulundugu_kat_cat_8  \
# 8262                           0                           0
# 8260                           0                           0
# 7889                           0                           0
# 7919                           0                           0
# 7923                           0                           0
#
#       binned_bulundugu_kat_cat_9
# 8262                           0
# 8260                           0
# 7889                           0
# 7919                           0
# 7923                           0
#
# [5 rows x 55 columns]

# %%
###################

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10255 entries, 8262 to 10947
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   rent                         10255 non-null  int32
#  1   latitude                     9191 non-null   float64
#  2   longitude                    9191 non-null   float64
#  3   oda_sayisi                   10255 non-null  object
#  4   salon_sayisi                 10255 non-null  object
#  5   brut_m2                      10255 non-null  int64
#  6   net_m2                       10255 non-null  int64
#  7   bina_yasi                    10255 non-null  int32
#  8   kat_sayisi                   10243 non-null  float64
#  9   esyali                       10255 non-null  int32
#  10  banyo_sayisi                 10247 non-null  float64
#  11  site_icerisinde_binary       10255 non-null  bool
#  12  dogu                         10255 non-null  bool
#  13  bati                         10255 non-null  bool
#  14  kuzey                        10255 non-null  bool
#  15  guney                        10255 non-null  bool
#  16  cephe_sayisi                 10255 non-null  int64
#  17  bulundugu_kat_num            8993 non-null   float64
#  18  binned_konut_sekli_0         10255 non-null  uint8
#  19  binned_konut_sekli_1         10255 non-null  uint8
#  20  binned_konut_sekli_3         10255 non-null  uint8
#  21  binned_konut_sekli_4         10255 non-null  uint8
#  22  binned_isinma_tipi_0         10255 non-null  uint8
#  23  binned_isinma_tipi_1         10255 non-null  uint8
#  24  binned_isinma_tipi_2         10255 non-null  uint8
#  25  binned_isinma_tipi_3         10255 non-null  uint8
#  26  binned_isinma_tipi_4         10255 non-null  uint8
#  27  binned_isinma_tipi_5         10255 non-null  uint8
#  28  binned_isinma_tipi_6         10255 non-null  uint8
#  29  binned_isinma_tipi_7         10255 non-null  uint8
#  30  binned_yapi_tipi_0.0         10255 non-null  uint8
#  31  binned_yapi_tipi_1.0         10255 non-null  uint8
#  32  binned_yapi_tipi_2.0         10255 non-null  uint8
#  33  binned_yapi_tipi_4.0         10255 non-null  uint8
#  34  yapinin_durumu_-             10255 non-null  uint8
#  35  yapinin_durumu_Sıfır         10255 non-null  uint8
#  36  yapinin_durumu_İkinci El     10255 non-null  uint8
#  37  binned_yakit_tipi_0          10255 non-null  uint8
#  38  binned_yakit_tipi_1          10255 non-null  uint8
#  39  binned_yakit_tipi_2          10255 non-null  uint8
#  40  kullanim_durumu_-            10255 non-null  uint8
#  41  kullanim_durumu_Boş          10255 non-null  uint8
#  42  kullanim_durumu_Kiracılı     10255 non-null  uint8
#  43  kullanim_durumu_Mülk Sahibi  10255 non-null  uint8
#  44  binned_bulundugu_kat_cat_0   10255 non-null  uint8
#  45  binned_bulundugu_kat_cat_1   10255 non-null  uint8
#  46  binned_bulundugu_kat_cat_10  10255 non-null  uint8
#  47  binned_bulundugu_kat_cat_11  10255 non-null  uint8
#  48  binned_bulundugu_kat_cat_2   10255 non-null  uint8
#  49  binned_bulundugu_kat_cat_3   10255 non-null  uint8
#  50  binned_bulundugu_kat_cat_4   10255 non-null  uint8
#  51  binned_bulundugu_kat_cat_6   10255 non-null  uint8
#  52  binned_bulundugu_kat_cat_7   10255 non-null  uint8
#  53  binned_bulundugu_kat_cat_8   10255 non-null  uint8
#  54  binned_bulundugu_kat_cat_9   10255 non-null  uint8
# dtypes: bool(5), float64(5), int32(3), int64(3), object(2), uint8(37)
# memory usage: 1.4+ MB

# %% [markdown]
# there is no missing value for the categorical variables

# %%
X, y = df.drop('rent', axis=1), df['rent']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=10)

# %% [markdown]
# impute and scale within cross validation

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler

def impute_and_scale(X_train, X_val, y_train, y_val, imputation_strategy='median'):
    numerical_cols = ['latitude', 'longitude', 'oda_sayisi', 'salon_sayisi', 'brut_m2',
               'net_m2', 'bina_yasi', 'kat_sayisi', 'banyo_sayisi',
               'site_icerisinde_binary', 'cephe_sayisi', 'bulundugu_kat_num']
    
    # fit the imputer on the train set and impute it
    imputer = SimpleImputer(missing_values=np.nan, strategy=imputation_strategy)
    train_imputed = pd.DataFrame(imputer.fit_transform(pd.concat([y_train, X_train], axis=1)), 
                                 columns=[y_train.name]+list(X_train.columns))
    
    # resplit the train set
    X_train_imputed, y_train = train_imputed.drop('rent', axis=1), train_imputed['rent']
    
    # fit the scaler on the train set and scale it
    scaler = RobustScaler()
    X_train_num_scaled = pd.DataFrame(scaler.fit_transform(X_train_imputed[numerical_cols]), columns=numerical_cols)
    
    X_train_scaled = X_train_imputed.copy()
    X_train_scaled[numerical_cols] = X_train_num_scaled
    
    # impute the val set
    val_imputed = pd.DataFrame(imputer.transform(pd.concat([y_val, X_val], axis=1)), 
                             columns=[y_val.name]+list(X_val.columns))
    
    # resplit the val set
    X_val_imputed, y_val = val_imputed.drop('rent', axis=1), val_imputed['rent']
    
    # scale the val set
    X_val_num_scaled = pd.DataFrame(scaler.transform(X_val_imputed[numerical_cols]), columns=numerical_cols)
    
    X_val_scaled = X_val_imputed.copy()
    X_val_scaled[numerical_cols] = X_val_num_scaled
    
    return X_train_scaled, X_val_scaled

# %%
def cross_validation(model, X, y, seed, n_splits=10, imputation_strategy='median'):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
    cv_scores = []

    for train_idx, val_idx in kf.split(X):
        x_tr, y_tr = X.iloc[train_idx], y.iloc[train_idx]
        x_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
        
        x_tr, x_val = impute_and_scale(x_tr, x_val, y_tr, y_val, imputation_strategy=imputation_strategy)
        
        model.fit(X=x_tr, y=np.power(y_tr, 1/3))
        pred = np.power(model.predict(x_val), 3)
        cv_scores.append(mean_absolute_error(y_val, pred))
        
    return np.mean(cv_scores)

# %% [markdown]
# # hyperparameter optimization

# %%
import optuna

# %%
def objective(trial, X_train, y_train, seed, n_splits):
    C = trial.suggest_loguniform('C', 0.01, 10)
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    degree = 0
    gamma = 'auto'
    epsilon = trial.suggest_loguniform('epsilon', 0.01, 1.0)

    if kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 5)
    elif kernel in ['rbf', 'sigmoid']:
        gamma = trial.suggest_loguniform('gamma', 0.001, 1.0)
    
    params = {'C':C, 'kernel':kernel, 'degree':degree, 
              'gamma':gamma, 'epsilon':epsilon}

    imputation = trial.suggest_categorical('imputation_strategy', ['mean', 'median'])
    
    # train and evaluate the model using the hyperparameters
    #model = SVR(C=C, kernel=kernel, degree=degree, gamma=gamma, epsilon=epsilon)
    model = SVR(**params)
    return cross_validation(model, X, y, seed=seed, n_splits=n_splits, imputation_strategy=imputation)

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(30))
study.optimize(lambda trial : objective(trial, X_train=X_train, y_train=y_train, seed=55, n_splits=5), n_trials=50)
# Out:
# [I 2023-02-19 17:12:12,624] A new study created in memory with name: no-name-2787b8bd-381a-4152-b5c3-595811413a42
# [I 2023-02-19 17:12:45,398] Trial 0 finished with value: 8934.026796666873 and parameters: {'C': 0.176629782647449, 'kernel': 'sigmoid', 'epsilon': 0.38665156637375564, 'gamma': 0.007671817645803569, 'imputation_strategy': 'median'}. Best is trial 0 with value: 8934.026796666873.
# [I 2023-02-19 17:13:27,777] Trial 1 finished with value: 6186.089758852566 and parameters: {'C': 0.6392261956576255, 'kernel': 'rbf', 'epsilon': 0.03441440768737148, 'gamma': 0.015320935809131336, 'imputation_strategy': 'median'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:14:00,174] Trial 2 finished with value: 15776.89120097537 and parameters: {'C': 0.2165734703535194, 'kernel': 'sigmoid', 'epsilon': 0.13239636267930094, 'gamma': 0.017221410595336082, 'imputation_strategy': 'median'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:14:33,827] Trial 3 finished with value: 8402924704.933118 and parameters: {'C': 1.1349300453658466, 'kernel': 'poly', 'epsilon': 0.09762038015265964, 'degree': 4, 'imputation_strategy': 'mean'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:15:00,256] Trial 4 finished with value: 8165.022828024875 and parameters: {'C': 0.011446650351769509, 'kernel': 'linear', 'epsilon': 0.06672399839923195, 'imputation_strategy': 'median'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:15:41,849] Trial 5 finished with value: 7519.124046105244 and parameters: {'C': 0.07260090339953962, 'kernel': 'rbf', 'epsilon': 0.04527676354030103, 'gamma': 0.006066374518026006, 'imputation_strategy': 'mean'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:16:08,198] Trial 6 finished with value: 9875.551581408174 and parameters: {'C': 0.04907496209260848, 'kernel': 'sigmoid', 'epsilon': 0.015851532773145636, 'gamma': 0.0010805965568345688, 'imputation_strategy': 'mean'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:16:32,340] Trial 7 finished with value: 7886.830815322866 and parameters: {'C': 0.8161306532202208, 'kernel': 'linear', 'epsilon': 0.038666395227931395, 'imputation_strategy': 'mean'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:17:01,492] Trial 8 finished with value: 35146155830.29673 and parameters: {'C': 5.1507036169357985, 'kernel': 'sigmoid', 'epsilon': 0.016994801573832197, 'gamma': 0.576300584194885, 'imputation_strategy': 'median'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:17:38,272] Trial 9 finished with value: 7866.737985482236 and parameters: {'C': 2.094117757324089, 'kernel': 'linear', 'epsilon': 0.01125404034202321, 'imputation_strategy': 'mean'}. Best is trial 1 with value: 6186.089758852566.
# [I 2023-02-19 17:18:10,215] Trial 10 finished with value: 5246.500910932205 and parameters: {'C': 9.326243251747671, 'kernel': 'rbf', 'epsilon': 0.5146225454576053, 'gamma': 0.13057270453163922, 'imputation_strategy': 'median'}. Best is trial 10 with value: 5246.500910932205.
# [I 2023-02-19 17:18:32,244] Trial 11 finished with value: 5262.403052130181 and parameters: {'C': 5.425253952358368, 'kernel': 'rbf', 'epsilon': 0.9386510862940566, 'gamma': 0.10270688459699641, 'imputation_strategy': 'median'}. Best is trial 10 with value: 5246.500910932205.
# [I 2023-02-19 17:18:58,874] Trial 12 finished with value: 5318.011796118621 and parameters: {'C': 9.402291085817062, 'kernel': 'rbf', 'epsilon': 0.950580722561993, 'gamma': 0.158216195891017, 'imputation_strategy': 'median'}. Best is trial 10 with value: 5246.500910932205.
# [I 2023-02-19 17:19:19,610] Trial 13 finished with value: 5300.829355644722 and parameters: {'C': 3.742140573603704, 'kernel': 'rbf', 'epsilon': 0.9965529543179159, 'gamma': 0.10811667123687418, 'imputation_strategy': 'median'}. Best is trial 10 with value: 5246.500910932205.
# [I 2023-02-19 17:19:50,624] Trial 14 finished with value: 5239.483032621742 and parameters: {'C': 8.600180329778576, 'kernel': 'rbf', 'epsilon': 0.4676682188494261, 'gamma': 0.1232350551967559, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:20:10,378] Trial 15 finished with value: 17185.85657399016 and parameters: {'C': 9.231524633856942, 'kernel': 'poly', 'epsilon': 0.3190873598796958, 'degree': 2, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:20:38,778] Trial 16 finished with value: 8421.094427909493 and parameters: {'C': 3.728087809543095, 'kernel': 'rbf', 'epsilon': 0.3634767210390207, 'gamma': 0.887044427142492, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:21:04,919] Trial 17 finished with value: 6053.580749257163 and parameters: {'C': 1.4425764463259132, 'kernel': 'rbf', 'epsilon': 0.20029647419834964, 'gamma': 0.2587069543226568, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:21:27,786] Trial 18 finished with value: 5493.748500043507 and parameters: {'C': 2.2546556623555487, 'kernel': 'rbf', 'epsilon': 0.5575747362122537, 'gamma': 0.04972450779474423, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:21:47,929] Trial 19 finished with value: 11761490929407.277 and parameters: {'C': 0.5066079913533521, 'kernel': 'poly', 'epsilon': 0.19509371542580486, 'degree': 5, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:22:20,130] Trial 20 finished with value: 5535.509902198562 and parameters: {'C': 9.91380572665308, 'kernel': 'rbf', 'epsilon': 0.5672946878534537, 'gamma': 0.2569764781894566, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:22:43,841] Trial 21 finished with value: 5308.456444310734 and parameters: {'C': 4.960463036799201, 'kernel': 'rbf', 'epsilon': 0.6636087645642818, 'gamma': 0.071407120731553, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:23:05,611] Trial 22 finished with value: 5350.494189582714 and parameters: {'C': 2.6688664040431624, 'kernel': 'rbf', 'epsilon': 0.7114157220235423, 'gamma': 0.0842144564926323, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:23:35,621] Trial 23 finished with value: 5340.317981609235 and parameters: {'C': 6.423391186314056, 'kernel': 'rbf', 'epsilon': 0.46791793666106574, 'gamma': 0.20085853320868094, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:24:02,040] Trial 24 finished with value: 5376.640188459648 and parameters: {'C': 5.406671697817489, 'kernel': 'rbf', 'epsilon': 0.29123457657355706, 'gamma': 0.049121893924840336, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:24:25,691] Trial 25 finished with value: 6472.69444602539 and parameters: {'C': 2.7639545198473523, 'kernel': 'rbf', 'epsilon': 0.7283854009852774, 'gamma': 0.3920369023196262, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:24:49,708] Trial 26 finished with value: 5390.346450567531 and parameters: {'C': 1.7831929608966448, 'kernel': 'rbf', 'epsilon': 0.45038408889602116, 'gamma': 0.12670911735069645, 'imputation_strategy': 'mean'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:25:08,012] Trial 27 finished with value: 15879.544969909766 and parameters: {'C': 6.487080845380683, 'kernel': 'poly', 'epsilon': 0.25106821452064504, 'degree': 2, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:25:48,138] Trial 28 finished with value: 7802.028158562762 and parameters: {'C': 3.2754421749090032, 'kernel': 'linear', 'epsilon': 0.9864725694692209, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:26:16,700] Trial 29 finished with value: 362548248.96402216 and parameters: {'C': 1.2104760493806006, 'kernel': 'sigmoid', 'epsilon': 0.46120636339240517, 'gamma': 0.43019776838392204, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:26:50,400] Trial 30 finished with value: 5261.825539676434 and parameters: {'C': 9.518667491789445, 'kernel': 'rbf', 'epsilon': 0.4053323567873089, 'gamma': 0.14788286177882037, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:27:21,567] Trial 31 finished with value: 5264.315893707679 and parameters: {'C': 7.151167251415476, 'kernel': 'rbf', 'epsilon': 0.3931413789475608, 'gamma': 0.16024014830813607, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:27:49,696] Trial 32 finished with value: 5250.533386173311 and parameters: {'C': 9.81639074871119, 'kernel': 'rbf', 'epsilon': 0.6361835856337094, 'gamma': 0.08620672432657232, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:28:18,993] Trial 33 finished with value: 5299.661799342343 and parameters: {'C': 9.268187625697442, 'kernel': 'rbf', 'epsilon': 0.343943853510176, 'gamma': 0.060664801096941334, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:28:48,832] Trial 34 finished with value: 5534.720497735436 and parameters: {'C': 4.039801506494203, 'kernel': 'rbf', 'epsilon': 0.24343583859929874, 'gamma': 0.2510105412346767, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:29:13,227] Trial 35 finished with value: 5272.340744447673 and parameters: {'C': 3.7944196504152012, 'kernel': 'rbf', 'epsilon': 0.5614292938545078, 'gamma': 0.11443384712770381, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:29:36,857] Trial 36 finished with value: 1846699484.3841813 and parameters: {'C': 6.950633527538976, 'kernel': 'sigmoid', 'epsilon': 0.1411995800699071, 'gamma': 0.03713299206632028, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:30:01,173] Trial 37 finished with value: 5509.389011080899 and parameters: {'C': 1.9271187740227413, 'kernel': 'rbf', 'epsilon': 0.4262112836169691, 'gamma': 0.185506598616772, 'imputation_strategy': 'mean'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:30:42,788] Trial 38 finished with value: 7882.381552109029 and parameters: {'C': 3.0030071765184174, 'kernel': 'linear', 'epsilon': 0.2943218528629914, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:31:04,655] Trial 39 finished with value: 53134071159041.86 and parameters: {'C': 6.84583434215614, 'kernel': 'poly', 'epsilon': 0.7263678597275075, 'degree': 5, 'imputation_strategy': 'mean'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:31:39,135] Trial 40 finished with value: 5268.036043999499 and parameters: {'C': 9.920400421671598, 'kernel': 'rbf', 'epsilon': 0.09593723669818578, 'gamma': 0.07590180989774249, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:32:02,557] Trial 41 finished with value: 5260.463156556337 and parameters: {'C': 4.850709627774935, 'kernel': 'rbf', 'epsilon': 0.7546041533665591, 'gamma': 0.10702327727586773, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:32:29,202] Trial 42 finished with value: 5251.879715844025 and parameters: {'C': 4.720868548858037, 'kernel': 'rbf', 'epsilon': 0.5025158737679626, 'gamma': 0.13195659258998013, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:32:53,879] Trial 43 finished with value: 5274.3242369606905 and parameters: {'C': 4.270623938657446, 'kernel': 'rbf', 'epsilon': 0.528372200750909, 'gamma': 0.09519921193639927, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:33:17,994] Trial 44 finished with value: 467264432.3237734 and parameters: {'C': 4.6447490366984345, 'kernel': 'sigmoid', 'epsilon': 0.8096727287477791, 'gamma': 0.031945813561107046, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:33:41,449] Trial 45 finished with value: 5658.68569932028 and parameters: {'C': 0.8629198197782625, 'kernel': 'rbf', 'epsilon': 0.6262932960712018, 'gamma': 0.057490272674955836, 'imputation_strategy': 'mean'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:34:42,994] Trial 46 finished with value: 7838.133615855566 and parameters: {'C': 5.741442743649162, 'kernel': 'linear', 'epsilon': 0.7891833100872329, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:35:07,556] Trial 47 finished with value: 5751.31139664867 and parameters: {'C': 2.7022820491441237, 'kernel': 'rbf', 'epsilon': 0.5246398972716555, 'gamma': 0.020767134975382698, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:35:31,902] Trial 48 finished with value: 5262.45291776007 and parameters: {'C': 7.155133200388271, 'kernel': 'rbf', 'epsilon': 0.8306167672197131, 'gamma': 0.0854461505805041, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.
# [I 2023-02-19 17:35:54,537] Trial 49 finished with value: 5468.19444231032 and parameters: {'C': 1.5430674335257435, 'kernel': 'rbf', 'epsilon': 0.6662808006031373, 'gamma': 0.12223025627947792, 'imputation_strategy': 'median'}. Best is trial 14 with value: 5239.483032621742.

# %%
study.best_params
# Out:
# {'C': 8.600180329778576,
#  'kernel': 'rbf',
#  'epsilon': 0.4676682188494261,
#  'gamma': 0.1232350551967559,
#  'imputation_strategy': 'median'}

# %%
trials_df = study.trials_dataframe().sort_values('value', ascending=True)
trials_df.iloc[:15]
# Out:
#     number        value             datetime_start          datetime_complete  \
# 14      14  5239.483033 2023-02-19 17:19:19.611794 2023-02-19 17:19:50.623966
# 10      10  5246.500911 2023-02-19 17:17:38.273946 2023-02-19 17:18:10.215896
# 32      32  5250.533386 2023-02-19 17:27:21.568564 2023-02-19 17:27:49.696690
# 42      42  5251.879716 2023-02-19 17:32:02.558151 2023-02-19 17:32:29.202240
# 41      41  5260.463157 2023-02-19 17:31:39.136919 2023-02-19 17:32:02.557150
# 30      30  5261.825540 2023-02-19 17:26:16.701854 2023-02-19 17:26:50.400985
# 11      11  5262.403052 2023-02-19 17:18:10.216863 2023-02-19 17:18:32.244634
# 48      48  5262.452918 2023-02-19 17:35:07.556409 2023-02-19 17:35:31.902921
# 31      31  5264.315894 2023-02-19 17:26:50.400985 2023-02-19 17:27:21.567564
# 40      40  5268.036044 2023-02-19 17:31:04.656857 2023-02-19 17:31:39.135953
# 35      35  5272.340744 2023-02-19 17:28:48.833605 2023-02-19 17:29:13.227287
# 43      43  5274.324237 2023-02-19 17:32:29.203243 2023-02-19 17:32:53.879375
# 33      33  5299.661799 2023-02-19 17:27:49.697658 2023-02-19 17:28:18.993532
# 13      13  5300.829356 2023-02-19 17:18:58.874598 2023-02-19 17:19:19.610791
# 21      21  5308.456444 2023-02-19 17:22:20.131753 2023-02-19 17:22:43.840482
#
#                  duration  params_C  params_degree  params_epsilon  \
# 14 0 days 00:00:31.012172  8.600180            NaN        0.467668
# 10 0 days 00:00:31.941950  9.326243            NaN        0.514623
# 32 0 days 00:00:28.128126  9.816391            NaN        0.636184
# 42 0 days 00:00:26.644089  4.720869            NaN        0.502516
# 41 0 days 00:00:23.420231  4.850710            NaN        0.754604
# 30 0 days 00:00:33.699131  9.518667            NaN        0.405332
# 11 0 days 00:00:22.027771  5.425254            NaN        0.938651
# 48 0 days 00:00:24.346512  7.155133            NaN        0.830617
# 31 0 days 00:00:31.166579  7.151167            NaN        0.393141
# 40 0 days 00:00:34.479096  9.920400            NaN        0.095937
# 35 0 days 00:00:24.393682  3.794420            NaN        0.561429
# 43 0 days 00:00:24.676132  4.270624            NaN        0.528372
# 33 0 days 00:00:29.295874  9.268188            NaN        0.343944
# 13 0 days 00:00:20.736193  3.742141            NaN        0.996553
# 21 0 days 00:00:23.708729  4.960463            NaN        0.663609
#
#     params_gamma params_imputation_strategy params_kernel     state
# 14      0.123235                     median           rbf  COMPLETE
# 10      0.130573                     median           rbf  COMPLETE
# 32      0.086207                     median           rbf  COMPLETE
# 42      0.131957                     median           rbf  COMPLETE
# 41      0.107023                     median           rbf  COMPLETE
# 30      0.147883                     median           rbf  COMPLETE
# 11      0.102707                     median           rbf  COMPLETE
# 48      0.085446                     median           rbf  COMPLETE
# 31      0.160240                     median           rbf  COMPLETE
# 40      0.075902                     median           rbf  COMPLETE
# 35      0.114434                     median           rbf  COMPLETE
# 43      0.095199                     median           rbf  COMPLETE
# 33      0.060665                     median           rbf  COMPLETE
# 13      0.108117                     median           rbf  COMPLETE
# 21      0.071407                     median           rbf  COMPLETE

# %%
X_train_preprocessed, X_test_preprocessed = impute_and_scale(X_train, X_test, y_train, y_test, imputation_strategy='median')

# %%
model_params={'C': 8.600180329778576,
             'kernel': 'rbf',
             'epsilon': 0.4676682188494261,
             'gamma': 0.1232350551967559}

model = SVR(**model_params)
model.fit(X_train_preprocessed, np.power(y_train, 1/3))
# Out:
# SVR(C=8.600180329778576, epsilon=0.4676682188494261, gamma=0.1232350551967559)

# %%
preds = np.power(model.predict(X_test_preprocessed), 3)
mean_absolute_error(y_test, preds)
# Out:
# 5056.099147406984

# %%
# with open('svr_trained', 'wb') as f:
#     _pickle.dump(model, f)
